# %% [markdown]
# # Fail-closed boundaries / unsupported scenarios
#
# **Curriculum id:** `05_fail_closed_boundaries`
# **Runtime class:** `cpu_local_fast`
# **hardware_execution:** `false`
#
# unsupported scenarios + refuse invent-green
#
# Claim boundary: differentiable-lane onboarding only; no live QPU; public API names only.

# %%
# SCPN differentiable curriculum cell — public API only; no secrets.
# Execute against the installed package, not invent-green hardware.
from scpn_quantum_control.differentiable_notebook_curriculum import (
    assert_differentiable_curriculum_integrity,
    build_differentiable_curriculum_registry,
    get_curriculum_notebook,
)

row = get_curriculum_notebook("05_fail_closed_boundaries")
assert row.hardware_execution is False
assert_differentiable_curriculum_integrity(build_differentiable_curriculum_registry())
print("CURRICULUM_OK", "05_fail_closed_boundaries", row.runtime_class)
